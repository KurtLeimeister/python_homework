# %% [markdown]
# # 1-4.3 Intro Python Practice
# ## Conditionals
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - **control code flow with `if`... `else` conditional logic**
#   - using Boolean string methods (`.isupper(), .isalpha(), .startswith()...`)
#   - using comparision (`>, <, >=, <=, ==, !=`)
#   - using Strings in comparisons

# %% [markdown]
# ## `if else`

# %%
# [ ] input avariable: age as digit and cast to int
# if age greater than or equal to 12 then print message on age in 10 years 
# or else print message "It is good to be" age

age = input('Please enter your age as a number: ')

if age.isdigit():
    if int(age)<=12:
        print('In ten years you will be '+str(int(age)+10)+' years old.')
    else:
        print('It is good to be '+age)
else:
    print('Age should be a positive natural number')
# Out:
# Please enter your age as a number: 4
# In ten years you will be 14 years old.

# %%
# [ ] input a number 
# if number IS a digit string then cast to int
# print number "greater than 100 is" True/False
# if number is NOT a digit string then message the user that "only int is accepted"
number=input('Please enter a number: ')

if number.isdigit():
    number=int(number)
    print('Greater than 100 is '+str(number>100))
else:
    print('Only integers are accepted')
# Out:
# Please enter a number: 99
# Greater than 100 is False

# %% [markdown]
# ### Guessing a letter A-Z
# **check_guess()** takes 2 string arguments: **letter and guess** (both expect single alphabetical character)
#     - if guess is not an alpha character print invalid and return False
#     - test and print if guess is "high" or "low" and return False
#     - test and print if guess is "correct" and return True

# %%
# [ ] create check_guess()
# call with test
# '123'.__len__() = 3

def check_guess(letter, guess):
    guess=str(guess)
    if not (guess.isalpha() and guess.__len__()==1):
        print('Please guess a single letter')
    else:
        if guess==letter:
            print("correct")
        else:
            if guess>letter:
                print("high")
            else:
                print("low")
                
# nested if statements, so elegant....

# %%
# import module to generate random number
import random

# %%
# [ ] call check_guess with user input
print('We have randomly selected a single letter, please try to guess it.')
submission=input('Enter single letter: ')
# randomly pick an ASCII character between 65(A) and 91 (Z)
random_letter=chr(random.randint(65,91))
check_guess(random_letter,submission)
# Out:
# We have randomly selected a single letter, please try to guess it.
# Enter single letter: F
# high

# %% [markdown]
# ### Letter Guess
# **create letter_guess() function that gives user 3 guesses**
# - takes a letter character argument for the answer letter
# - gets user input for letter guess
# - calls check_guess() with answer and guess
# - End letter_guess if
#     - check_guess() equals True, return True
#     - or after 3 failed attempts, return False

# %%
# [ ] create letter_guess() function, call the function to test
def letter_guess():
    for i in range(9):
        guess=input('Enter single letter: ')
        check_guess('A',guess)

# %%
letter_guess()
# Out:
# Enter single letter: Ä
# high
# Enter single letter: A
# correct
# Enter single letter: a
# high
# Enter single letter: ä
# high
# Enter single letter: Zebra
# Please guess a single letter
# Enter single letter: 2
# Please guess a single letter
# Enter single letter: 22
# Please guess a single letter
# Enter single letter: '
# Please guess a single letter
# Enter single letter: "
# Please guess a single letter

# %% [markdown]
# ### Pet Conversation
# **ask the user for a sentence about a pet and then reply**
# - get user input in variable: about_pet
# - using a series of **if** statements respond with appropriate conversation
#   - check if "dog" is in the string about_pet (sample reply "Ah, a dog")
#   - check if "cat" is in the string about_pet
#   - check if 1 or more animal is in string about_pet
# - no need for **else**'s
# - finish with thanking for the story

# %%
# [ ] complete pet conversation

def pet_story_3(sentence):
    story=sentence.lower()
    has_dog = 'dog' in story
    has_cat = 'cat' in story
    has_snake = 'snake' in story
    if (has_dog and has_cat):
        print('Catdog! Catdog!')
        return
    if has_dog:
        print('Woof!')
    if has_cat:
        print('Mewo!')
    if has_snake:
        print('Enough is enough! Ive had it with these motherf$cking snakes on this motherf$cking plane!')

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft

# %%
pet_experience=input('Please write a sentence about your most memorable experience involving a pet: \n')
pet_story_3(pet_experience)
# Out:
# Please write a sentence about your most memorable experience involving a pet:
# It's a cat. It's a dog.

# %%
pet_experience=input('Please write a sentence about your most memorable experience involving a pet: \n')
pet_story_3(pet_experience)
# Out:
# Please write a sentence about your most memorable experience involving a pet:
# My roommate lost his anaconda, it's harder than you would think to catch a large snake...
# Mewo!
# Enough is enough! Ive had it with these motherf$cking snakes on this motherf$cking plane!
